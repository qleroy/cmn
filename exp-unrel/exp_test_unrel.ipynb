# %%
# cd to root project

# %%
cd ~/mva/recvis/project/cmn/
# Out:
# /Users/quentinleroy/mva/recvis/project/cmn

# %%
from __future__ import absolute_import, division, print_function

import sys
import os; os.environ['CUDA_VISIBLE_DEVICES'] = ''  # using GPU 0

import tensorflow as tf
import numpy as np
import skimage.io
import skimage.transform

from models import visgeno_attention_model, spatial_feat, fastrcnn_vgg_net
from util.visgeno_rel_train.rel_data_reader import DataReader
from util import loss, eval_tools, text_processing

# %%
################################################################################
# Parameters
################################################################################

# Model Params
T = 20
num_vocab = 72704
embed_dim = 300
lstm_dim = 1000

# Data Params
# imdb_file = './exp-visgeno-rel/data/imdb/imdb_val.npy'
imdb_file = './exp-unrel/unrel_imdb.npy'
vocab_file = './word_embedding/vocabulary_72700.txt'
im_mean = visgeno_attention_model.fastrcnn_vgg_net.channel_mean

# Snapshot Params
model_file = './downloaded_models/visgeno_attbilstm_strong_iter_360000.tfmodel'

visualize_dir = './exp-visgeno-rel/results/unrel_attbilstm_strong_iter_360000.val/'

# %%
################################################################################
# Network
################################################################################

im_batch = tf.placeholder(tf.float32, [1, None, None, 3])
bbox_batch = tf.placeholder(tf.float32, [None, 5])
spatial_batch = tf.placeholder(tf.float32, [None, 5])
text_seq_batch = tf.placeholder(tf.int32, [T, None])

# %%
scores = visgeno_attention_model.visgeno_attbilstm_net(im_batch, bbox_batch, spatial_batch,
    text_seq_batch, num_vocab, embed_dim, lstm_dim, False, False)

# %%
np.random.seed(3)
reader = DataReader(imdb_file, vocab_file, im_mean, shuffle=False, max_bbox_num=10000, max_rel_num=10000)
# Out:
# Loading ROI data from file...Done.

# %%
################################################################################
# Snapshot and log
################################################################################

# Snapshot saver
snapshot_saver = tf.train.Saver()

# Start Session
# sess = tf.Session(config=tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True)))

sess = tf.Session()

# tf.reset_default_graph()


# Run Initialization operations
snapshot_saver.restore(sess, model_file)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

vocab_list = [w.strip() for w in open(vocab_file).readlines()]
def vocab_indices2sentence(indices):
    return ' '.join([vocab_list[idx] for idx in indices if idx != 0])
def print_bbox(bboxes, style='r-', color='#00FF00', linewidth=5):
    """A utility function to help visualizing boxes."""
    bboxes = np.array(bboxes).reshape((-1, 4))
    for bbox in bboxes:
        xmin, ymin, xmax, ymax = bbox
        xmin-=(linewidth+3)
        ymin-=(linewidth+3)
        xmax+=(linewidth+3)
        ymax+=(linewidth+3)
        plt.plot([xmin, xmax, xmax, xmin, xmin],
                 [ymin, ymin, ymax, ymax, ymin], style, color=color, linewidth=linewidth)

# %%
################################################################################
# Optimization loop
################################################################################

if not os.path.isdir(visualize_dir):
    os.mkdir(visualize_dir)

# Run optimization
for n_iter in range(reader.num_batch):
    batch = reader.read_batch()
    
    ###
    # continue if the batch does not contain any relationship
    # and increment n_iter so that the first few batches are not read once again in case of
    ###
    if batch is None:
        n_iter = n_iter + 1
        continue
        
        
    print('\tthis batch: N_lang = %d, N_bbox = %d' %
          (batch['expr_obj1_batch'].shape[1], batch['bbox_batch'].shape[0]))

    k = batch['expr_obj1_batch'].shape[1] // 2

    # Forward and Backward pass
    scores_val, ((probs_obj1, probs_obj2, probs_rel),) = sess.run((scores,
            tf.get_collection("attention_probs")),
        feed_dict={
            im_batch            : batch['im_batch'],
            bbox_batch          : batch['bbox_batch'],
            spatial_batch       : batch['spatial_batch'],
            text_seq_batch      : batch['text_seq_batch']
        })

    
    expr = vocab_indices2sentence(batch['text_seq_batch'][:, k])
    is_not_pad = batch['text_seq_batch'][:, k] > 0
    words = [vocab_list[idx] for idx in batch['text_seq_batch'][is_not_pad, k]]

    im = (batch['im_batch'][0] + im_mean).astype(np.uint8)
    bboxes = batch['bbox_batch'][:, 1:]

    plt.figure(figsize=(8, 6))
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, words + ['']*(10-len(words)), rotation=90, fontsize=20)
    plt.yticks([0, 1, 2], ['$a_{subj}$', '$a_{rel}$  ', '$a_{obj}$  '], fontsize=28)
    attention_mat = np.hstack((probs_obj1[is_not_pad, k], probs_rel[is_not_pad, k], probs_obj2[is_not_pad, k])).T
    attention_mat = np.hstack((attention_mat, np.zeros((3, 10-len(words)), attention_mat.dtype)))
    plt.imshow(attention_mat, interpolation='nearest', cmap='Reds')
    plt.colorbar()
    plt.savefig(visualize_dir + '%08d_att.png' % n_iter)

    plt.figure(figsize=(8, 6))
    gt_l = batch['label_batch'][k]
    plt.imshow(im)
    print_bbox(bboxes[gt_l // len(bboxes)], '-', color='#FF0000')
    print_bbox(bboxes[gt_l % len(bboxes)], '--', color='#00FF00')
    plt.title(expr + ' (ground-truth)')
    plt.axis([-10, im.shape[1]+10, -10, im.shape[0]+10])
    plt.gca().invert_yaxis()
    plt.axis('off')
    plt.savefig(visualize_dir + '%08d_gt.png' % n_iter)

    plt.figure(figsize=(8, 6))
    pred_l = np.argmax(scores_val[k])
    plt.imshow(im)
    print_bbox(bboxes[pred_l // len(bboxes)], '-', color='#FF0000')
    print_bbox(bboxes[pred_l % len(bboxes)], '--', color='#00FF00')
    plt.title(expr + ' (prediction)')
    plt.axis([-10, im.shape[1]+10, -10, im.shape[0]+10])
    plt.gca().invert_yaxis()
    plt.axis('off')
    plt.savefig(visualize_dir + '%08d_pred.png' % n_iter)
    
#     plt.close('all')
# Out:
# data reader: epoch = 0, batch = 5 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 6 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 7 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 8 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 9 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 10 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 11 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# /anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# data reader: epoch = 0, batch = 12 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 13 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 14 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 15 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 16 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 17 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 18 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 19 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 20 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 21 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 22 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 23 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 24 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 25 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 26 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 27 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 28 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 29 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 30 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 31 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 32 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 33 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 34 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 35 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 36 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 37 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 38 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 39 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 40 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 41 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 42 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 43 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 44 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 45 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 46 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 47 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 48 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 49 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 50 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 51 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 52 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 53 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 54 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 55 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 56 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 57 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 58 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 59 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 60 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 61 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 62 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 63 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 64 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 65 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 66 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 67 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 68 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 69 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 70 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 71 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 72 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 73 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 74 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 75 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 76 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 77 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 78 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 79 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 80 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 81 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 82 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 83 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 84 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 85 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 86 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 87 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 88 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 89 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 90 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 91 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 92 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 93 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 94 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 95 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 96 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 97 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 98 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 99 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 100 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 101 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch =
/ 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 491 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 492 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 493 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 494 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 495 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 496 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 497 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 498 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 499 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 500 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 501 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 502 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 503 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 504 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 505 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 506 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 507 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 508 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 509 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 510 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 511 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 512 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 513 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 514 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 515 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 516 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 517 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 518 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 519 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 520 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 521 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 522 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 523 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 524 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 525 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 526 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 527 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 528 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 529 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 530 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 531 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 532 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 533 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 534 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 535 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 536 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 537 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 538 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 539 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 540 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 541 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 542 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 543 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 544 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 545 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 546 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 547 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 548 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 549 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 550 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 551 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 552 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 553 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 554 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 555 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 556 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 557 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 558 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 559 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 560 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 561 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 562 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 563 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 564 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 565 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 566 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 567 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 568 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 569 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 570 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 571 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 572 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 573 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 574 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 575 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 576 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 577 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 578 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 579 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 580 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 581 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 582 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 583 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 584 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 585 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 586 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 587 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 588 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 589 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 590 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 591 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 592 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 593 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 594 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 595 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 596 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 597 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 598 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 599 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 600 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 601 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 602 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 603 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 604 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 605 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 606 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 607 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 608 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# ...
# data reader: epoch = 0, batch = 849 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 850 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 851 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 852 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 853 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 854 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 855 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 856 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 857 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 858 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 859 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 860 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 861 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 862 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 863 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 864 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 865 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 866 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 867 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 868 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 869 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 870 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 871 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 872 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 873 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 874 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 875 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 876 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 877 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 878 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 879 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 880 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 881 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 882 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 883 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 884 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 885 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 886 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 887 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 888 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 889 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 890 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 891 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 892 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 893 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 894 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 895 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 896 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 897 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 898 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 899 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 900 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 901 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 902 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 903 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 904 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 905 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 906 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 907 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 908 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 909 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 910 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 911 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 912 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 913 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 914 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 915 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 916 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 917 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 918 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 919 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 920 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 921 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 922 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 923 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 924 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 925 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 926 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 927 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 928 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 929 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 930 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 931 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 932 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 933 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 934 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 935 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 936 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 937 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 938 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 939 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 940 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 941 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 942 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 943 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 944 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 945 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 946 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 947 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 948 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 949 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 950 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 951 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 952 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 953 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 954 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 955 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 956 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 957 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 958 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 959 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 960 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 961 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 962 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 963 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 964 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 965 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 966 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 967 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 968 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 969 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 970 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 971 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 972 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 973 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 974 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 975 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 976 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 977 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 978 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 979 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 980 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 981 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 982 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 983 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 984 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 985 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 986 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 987 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 988 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 989 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 990 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 991 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 992 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 993 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 994 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 995 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 996 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 997 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 998 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 999 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1000 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1001 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1002 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1003 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1004 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1005 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1006 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1007 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1008 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1009 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1010 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1011 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1012 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1013 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1014 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1015 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1016 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1017 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1018 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1019 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1020 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1021 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1022 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1023 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1024 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1025 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1026 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1027 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1028 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1029 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1030 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1031 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1032 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/anaconda/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/anaconda/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/quentinleroy/mva/recvis/project/cmn/util/visgeno_rel_train/rel_data_reader.py", line 28, in run_prefetch
#     vocab_dict, T, max_bbox_num, max_rel_num)
#   File "/Users/quentinleroy/mva/recvis/project/cmn/util/visgeno_rel_train/prepare_batch.py", line 25, in load_one_batch
#     im_processed = im_resized*255 - im_mean
# ValueError: operands could not be broadcast together with shapes (1000,523,4) (3,)
# data reader: epoch = 0, batch = 1033 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1034 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1035 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1036 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1037 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1038 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1039 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1040 / 1071
# 	this batch: N_lang = 1, N_bbox = 2
# data reader: epoch = 0, batch = 1041 / 1071
# data reader: waiting for file input (IO is slow)...
